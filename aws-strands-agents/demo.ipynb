# %% [markdown]
# # AWS Strands Agent Test
#
# ## Prerequisites
#
# Ensure you are authenticated with AWS (for example, run `aws sso login --profile YOUR_PROFILE` or configure your AWS credentials) before accessing your runtime.

# %%
arn = ""  # TODO enter the ARN of your AgentCoreRuntime

# %%
# !pip install botocore[crt]

import json
from uuid import uuid4

import boto3
from IPython.display import display, Markdown, clear_output

# %%
agent_core_client = boto3.client('bedrock-agentcore')

def send_request(_session_id: str, _actor_id: str, prompt: str):
    payload = json.dumps({"prompt": prompt, "actor_id": _actor_id}).encode()

    # Invoke the agent with a streaming response
    response = agent_core_client.invoke_agent_runtime(
        agentRuntimeArn=arn,
        runtimeSessionId=_session_id,
        payload=payload
    )

    # Handle streaming response
    accumulated = ""
    for line in response["response"].iter_lines(chunk_size=10):
        if line:
            line = line.decode("utf-8")
            if line.startswith("data: "):
                line = line[6:]
                # Remove quotes and unescape
                try:
                    parsed = json.loads(line)
                except Exception:
                    parsed = line
                accumulated += str(parsed)
                clear_output(wait=True)
                display(Markdown(accumulated))

# %%
# create a new session
session_id = str(uuid4())

# %%
actor_id = "user-1"

# %%
actor_id = "user-2"

# %%
send_request(session_id, actor_id, "Always answer very short and as a pirate")
# Out:
# Ahoy matey! I'll be answerin' yer questions short 'n sweet like a true pirate! ⚓🏴‍☠️
#
# What be ye needin' from this here database, savvy?

# %%
send_request(session_id, actor_id, "What are the top 3 companies by revenue")
# Out:
# Arrr! Microsoft, Foxconn, Meta be the richest! 🏴‍☠️💰

# %%
send_request(session_id, actor_id, "What are the competitors of the third one")
# Out:
# Arrr! Meta's rivals be: Google, Apple, Twitter, TikTok, Microsoft, Samsung, Snap, Alphabet, Snapchat! ⚔️🏴‍☠️

# %%
# you need to wait 60 sec so the preferences get stored in long term memory
send_request(session_id, actor_id, "What are my preferences")
# Out:
# Ahoy! Ye like:
# - Short pirate talk 🏴‍☠️
# - Company revenue rankings 💰
#
# That be it, matey!

# %%
session_id = str(uuid4())
send_request(session_id, actor_id, "Forget about my preferences")
# Out:
# Aye aye, captain! Preferences be cleared from me memory! 🏴‍☠️All done, matey!

# %%
send_request(session_id, actor_id, "What are the top 3 companies by revenue")
# Out:
# I'll help you find the top 3 companies by revenue. Let me first check the database schema to see what data is available.Great! I can see there's an `Organization` node with a `revenue` property. Let me query for the top 3 companies by revenue.Here are the **top 3 companies by revenue**:
#
# 1. **Microsoft Corporation** - $198.27 billion
# 2. **Foxconn** - $175 billion
# 3. **Meta Platforms** - $116.61 billion
#
# Microsoft leads the pack with nearly $200 billion in revenue, followed by Foxconn (the major electronics manufacturer) and Meta Platforms (formerly Facebook).
